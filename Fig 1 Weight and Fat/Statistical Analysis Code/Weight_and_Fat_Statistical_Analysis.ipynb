# %% [markdown]
# # Performing statistical analysis for weight and final adiposity
#
# Download timeseries for weight and terminate data from the Dropbox/../Figures/Data for Figures. Perform statistical analysis for (A) weight vs. time and (B) final adiposity for all 4 experimental groups
#
# In this analysis, I perform 3 types of statistical test for both body weight and adiposity:
# 1. 2-sample independent t-tests
# 2. ANOVA
# 3. MannU Whitney Analysis

# %%
#----------------------------------------------------------
# Import important libraries
#----------------------------------------------------------
import pandas as pd
import numpy as np
import datetime
import os 
import matplotlib.pyplot as plt
import seaborn as sns
import math
from scipy import stats
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
import statsmodels.stats.multicomp
import matplotlib.dates as mdates
sns.set()

# %% [markdown]
# ## Download Body Weight data

# %%
#----------------------------------------------------------
# Import body weight data
#----------------------------------------------------------
weight_data_location = "https://www.dropbox.com/s/wktthzuhv7vgvox/2018VT%20-%20final%20weight%20log.csv?dl=1"
body_weight = pd.read_csv(weight_data_location).T
body_weight.columns = body_weight.iloc[0]

metafile = body_weight.iloc[1:3].T
body_weight.drop(['Rat', 'Diet', 'Feeding'], inplace = True)
metafile.head()
# Out:
#         Diet Feeding
# Rat
# 1    control  ad lib
# 2    control  ad lib
# 3    control  ad lib
# 4    control  ad lib
# 5    control  ad lib

# %% [markdown]
# ## Download terminal data master document

# %%
#----------------------------------------------------------
# Import terminal data
#----------------------------------------------------------
master_data_location = 'https://www.dropbox.com/s/eu0szifsb9yimo3/2018VT_termination_data_master_document.csv?dl=1'
master_data = pd.read_csv(master_data_location, index_col=0)
# Correct column names
master_data = master_data.rename(columns={" Leptin": "Leptin", "triglyceride (mg/mL)": "Triglyceride"})
master_data['group']=master_data.diet+' '+master_data.feeding_schedule
master_data.head()
# Out:
#         diet feeding_schedule  liver_weight  total_abdominal_fat  \
# Rat
# 1    control           ad lib          17.2                  4.6
# 2    control           ad lib          14.0                  5.4
# 3    control           ad lib          13.6                  5.5
# 4    control           ad lib          14.5                  5.2
# 5    control           ad lib          13.5                  7.4
#
#      total_gonadal_fat  total_fat_pad  final_BW    Leptin  Cholesterol  \
# Rat
# 1                  3.9            8.5       380  1.637628    82.053143
# 2                  3.4            8.8       318  2.032943   103.345415
# 3                  3.5            9.0       351  1.555637    55.869566
# 4                  4.7            9.9       357  2.997072    96.807567
# 5                  5.6           13.0       363  2.704246    81.771341
#
#      Triglyceride  GSP (umol/L)  Adiponectin           group
# Rat
# 1        0.942691    112.240742     4.988413  control ad lib
# 2        1.254153    121.759269     4.256736  control ad lib
# 3        0.228261    144.648151     6.666516  control ad lib
# 4        0.407609    155.222252     3.853354  control ad lib
# 5        0.619565    221.916665     4.382227  control ad lib

# %% [markdown]
# # Statistics Testing
# ## A.Body Weight
# ### Create a Body Weight dataframe specifically for ANOVA

# %%
#----------------------------------------------------------
#Created BW dataframe appropriate for ANOVA testing
#----------------------------------------------------------
body_weight_anova = pd.read_csv(weight_data_location, index_col = 0)
body_weight_anova['diet_and_schedule'] = body_weight_anova["Diet"].astype(str) +" "+ body_weight_anova["Feeding"].astype(str)
body_weight_anova.head()
# Out:
#         Diet Feeding  17-Sep  18-Sep  19-Sep  20-Sep  21-Sep  22-Sep  23-Sep  \
# Rat
# 1    control  ad lib      41      47      54      58      64      70      77
# 2    control  ad lib      41      45      50      54      58      64      69
# 3    control  ad lib      53      58      64      71      78      83      89
# 4    control  ad lib      41      45      50      54      59      64      70
# 5    control  ad lib      47      51      57      61      67      72      80
#
#      24-Sep  ...  1-Nov  2-Nov  3-Nov  4-Nov  5-Nov  6-Nov  7-Nov  8-Nov  \
# Rat          ...
# 1        85  ...    351    355    357    358    364    368    371    376
# 2        74  ...    293    298    298    302    304    308    311    315
# 3        94  ...    324    330    333    336    333    338    340    347
# 4        77  ...    331    337    338    345    342    347    351    355
# 5        87  ...    329    336    338    343    347    348    356    360
#
#      9-Nov  diet_and_schedule
# Rat
# 1      380     control ad lib
# 2      318     control ad lib
# 3      351     control ad lib
# 4      357     control ad lib
# 5      363     control ad lib
#
# [5 rows x 57 columns]

# %% [markdown]
# ## 1. Two Sample Independent T-Tests
# ### Cont AdLib vs HFHS AdLib (Before Day 28)
# This analysis is to examine how body weight between all HFHS rats differed from Control rats in the first 28 days (first phase) of the experiment. There are also t-tests for comparisons after Day 28.

# %%
cont_hfhs_t_test_results = {}
cont_adlib_cont_restr_t_test_results = {}
cont_adlib_hfhs_adlib_t_test_results = {}
hfhs_adlib_hfhs_restr_t_test_results = {}
cont_restr_hfhs_restr_t_test_results = {}

daynumber = 1
for day in body_weight.index:
    groupa = body_weight_anova.where((body_weight_anova.diet_and_schedule == "control ad lib") | (body_weight_anova.diet_and_schedule == "control restriction"))[day].dropna()
    groupb = body_weight_anova.where((body_weight_anova.diet_and_schedule == "HFHS ad lib") | (body_weight_anova.diet_and_schedule == "HFHS restriction"))[day].dropna()
    group1 = body_weight_anova.where(body_weight_anova.diet_and_schedule == "control ad lib")[day].dropna()
    group2 = body_weight_anova.where(body_weight_anova.diet_and_schedule == "control restriction")[day].dropna()
    group3 = body_weight_anova.where(body_weight_anova.diet_and_schedule == "HFHS ad lib")[day].dropna()
    group4 = body_weight_anova.where(body_weight_anova.diet_and_schedule == "HFHS restriction")[day].dropna()
    # Control AdLib + Control Restricted vs HFHS AdLib + HFHS Restricted - Only Search for Days Before ~27
    cont_hfhs_t_test_results["Day " + str(daynumber) + ": " + day + " - Control AdLib + Control Restricted vs HFHS AdLib + HFHS Restricted"] = stats.ttest_ind(groupa,groupb)
    # Control AdLib vs Control Restricted
    cont_adlib_cont_restr_t_test_results["Day " + str(daynumber) + ": " + day + " - Control AdLib vs Control Restricted"] = stats.ttest_ind(group1,group2)
    # Control Adlib vs HFHS Ad Lib - Only Search for Days After ~27
    cont_adlib_hfhs_adlib_t_test_results["Day " + str(daynumber) + ": " + day + " - Control Adlib vs HFHS Ad Lib"] = stats.ttest_ind(group1,group3)
    # HFHS AdLib vs HFHS Restricted
    hfhs_adlib_hfhs_restr_t_test_results["Day " + str(daynumber) + ": " + day + " - HFHS AdLib vs HFHS Restricted"] = stats.ttest_ind(group3,group4)
    # Control Restricted vs HFHS Restricted
    cont_restr_hfhs_restr_t_test_results["Day " + str(daynumber) + ": " + day + " - Control Restricted vs HFHS Restricted"] = stats.ttest_ind(group2,group4)
    daynumber += 1
# Control AdLib + Control Restricted vs HFHS AdLib + HFHS Restricted Results
cont_hfhs_t_test_results_df = pd.DataFrame.from_dict(cont_hfhs_t_test_results, orient='Index')
cont_hfhs_t_test_results_df.columns = ['statistic','pvalue']
cont_hfhs_significant_days = cont_hfhs_t_test_results_df[cont_hfhs_t_test_results_df.pvalue<0.05].drop_duplicates(subset='pvalue')

# Control AdLib vs Control Restricted Results
cont_adlib_cont_restr_t_test_results_df = pd.DataFrame.from_dict(cont_adlib_cont_restr_t_test_results, orient='Index')
cont_adlib_cont_restr_t_test_results_df.columns = ['statistic','pvalue']
cont_adlib_cont_restr_significant_days = cont_adlib_cont_restr_t_test_results_df[cont_adlib_cont_restr_t_test_results_df.pvalue<0.05].drop_duplicates(subset='pvalue')

# Control Adlib vs HFHS Ad Lib Results
cont_adlib_hfhs_adlib_t_test_results_df = pd.DataFrame.from_dict(cont_adlib_hfhs_adlib_t_test_results, orient='Index')
cont_adlib_hfhs_adlib_t_test_results_df.columns = ['statistic','pvalue']
cont_adlib_hfhs_adlib_significant_days = cont_adlib_hfhs_adlib_t_test_results_df[cont_adlib_hfhs_adlib_t_test_results_df.pvalue<0.05].drop_duplicates(subset='pvalue')

# HFHS AdLib vs HFHS Restricted Results
hfhs_adlib_hfhs_restr_t_test_results_df = pd.DataFrame.from_dict(hfhs_adlib_hfhs_restr_t_test_results, orient='Index')
hfhs_adlib_hfhs_restr_t_test_results_df.columns = ['statistic','pvalue']
hfhs_adlib_hfhs_restr_significant_days = hfhs_adlib_hfhs_restr_t_test_results_df[hfhs_adlib_hfhs_restr_t_test_results_df.pvalue<0.05].drop_duplicates(subset='pvalue')

# Control Restricted vs HFHS Restricted Results
cont_restr_hfhs_restr_t_test_results_df = pd.DataFrame.from_dict(cont_restr_hfhs_restr_t_test_results, orient='Index')
cont_restr_hfhs_restr_t_test_results_df.columns = ['statistic','pvalue']
cont_restr_hfhs_restr_significant_days = cont_restr_hfhs_restr_t_test_results_df[cont_restr_hfhs_restr_t_test_results_df.pvalue<0.05].drop_duplicates(subset='pvalue')

# %%
cont_hfhs_significant_days.to_csv("ControlvsHFHS_BeforeDay28_significant_days.csv")
cont_hfhs_significant_days.head()
# Out:
#                                                     statistic    pvalue
# Day 2: 18-Sep - Control AdLib + Control Restric...  -2.107341  0.042770
# Day 3: 19-Sep - Control AdLib + Control Restric...  -2.346541  0.025103
# Day 4: 20-Sep - Control AdLib + Control Restric...  -2.508241  0.017228
# Day 5: 21-Sep - Control AdLib + Control Restric...  -3.190456  0.003110
# Day 6: 22-Sep - Control AdLib + Control Restric...  -3.331162  0.002140

# %% [markdown]
# ### Control AdLib vs HFHS AdLib (After Day 28)

# %%
cont_adlib_hfhs_adlib_significant_days.iloc[16:21]
# Out:
#                                                statistic    pvalue
# Day 25: 11-Oct - Control Adlib vs HFHS Ad Lib  -2.632888  0.018824
# Day 26: 12-Oct - Control Adlib vs HFHS Ad Lib  -2.364131  0.031987
# Day 27: 13-Oct - Control Adlib vs HFHS Ad Lib  -2.174674  0.046066
# Day 28: 14-Oct - Control Adlib vs HFHS Ad Lib  -2.155829  0.047744
# Day 29: 15-Oct - Control Adlib vs HFHS Ad Lib  -2.365468  0.031903

# %% [markdown]
# ### Cont Res vs HFHS Res

# %%
cont_restr_hfhs_restr_significant_days.iloc[20:25]
# Out:
#                                                     statistic    pvalue
# Day 26: 12-Oct - Control Restricted vs HFHS Res...  -3.111502  0.006716
# Day 27: 13-Oct - Control Restricted vs HFHS Res...  -3.289082  0.004624
# Day 28: 14-Oct - Control Restricted vs HFHS Res...  -2.917510  0.010068
# Day 29: 15-Oct - Control Restricted vs HFHS Res...  -3.232084  0.005214
# Day 30: 16-Oct - Control Restricted vs HFHS Res...  -3.374097  0.003866

# %% [markdown]
# ### Cont AdLib vs Cont Res

# %%
cont_adlib_cont_restr_significant_days
# Out:
#                                                     statistic    pvalue
# Day 44: 30-Oct - Control AdLib vs Control Restr...   2.666408  0.016894
# Day 45: 31-Oct - Control AdLib vs Control Restr...   2.419130  0.027838
# Day 46: 1-Nov - Control AdLib vs Control Restri...   2.246678  0.039127

# %% [markdown]
# ### HFHS AdLib vs HFHS Res

# %%
hfhs_adlib_hfhs_restr_significant_days
# Out:
# Empty DataFrame
# Columns: [statistic, pvalue]
# Index: []

# %% [markdown]
# ## 2. ANOVA Analysis with PostHoc Tukey
# This analysis is to examine how body weight between 4 experimental groups differed from each other after day 28 (second phase) of the experiment. There are also ANOVA analyses for comparisons before Day 28 between all HFHS rats vs all Control rats

# %% [markdown]
# ### First, I'll check for normality with the Shapiro-Wilk Test. Results printed below reveal which group of rats and which day were the rats having a non-normal body weight population

# %%
daynumber = 1
for day in body_weight.index:
    # Divide the body weight data into 6 groups (all HFHS rats, all Control rats, control ad lib, control restriction, HFHS ad lib, HFHS restriction)
    groupa = body_weight_anova.where((body_weight_anova.diet_and_schedule == "control ad lib") | (body_weight_anova.diet_and_schedule == "control restriction"))[day].dropna()
    groupb = body_weight_anova.where((body_weight_anova.diet_and_schedule == "HFHS ad lib") | (body_weight_anova.diet_and_schedule == "HFHS restriction"))[day].dropna()
    group1 = body_weight_anova.where(body_weight_anova.diet_and_schedule == "control ad lib")[day].dropna()
    group2 = body_weight_anova.where(body_weight_anova.diet_and_schedule == "control restriction")[day].dropna()
    group3 = body_weight_anova.where(body_weight_anova.diet_and_schedule == "HFHS ad lib")[day].dropna()
    group4 = body_weight_anova.where(body_weight_anova.diet_and_schedule == "HFHS restriction")[day].dropna()
    before28 = [groupa, groupb]
    after28 = [group1, group2, group3, group4]
    # For the first phase of the experiment
    if daynumber < 28:
        for group in before28:
            # Check normality for 1. all HFHS rats and 2. all Control rats for each day
            w, p = stats.shapiro(group)
            if p < 0.05:
                print("Day: " + str(daynumber))
                print(str(day))
                print(group)
                print(p)
    # For the second phase of the experiment
    else:
        for group in after28:
            # Check normality for all 4 experimental groups for each day
            w, p = stats.shapiro(group)
            if p < 0.05:
                print("Day: " + str(daynumber))
                print(str(day))
                print(group)
                print(p)    
    daynumber += 1
# Out:
# Day: 31
# 17-Oct
# Rat
# 10    233.0
# 11    180.0
# 12    236.0
# 13    233.0
# 14    199.0
# 15    233.0
# 16    191.0
# 17    216.0
# 18    231.0
# Name: 17-Oct, dtype: float64
# 0.03178425878286362
# Day: 33
# 19-Oct
# Rat
# 10    253.0
# 11    196.0
# 12    249.0
# 13    254.0
# 14    221.0
# 15    250.0
# 16    203.0
# 17    232.0
# 18    251.0
# Name: 19-Oct, dtype: float64
# 0.033813685178756714
# Day: 34
# 20-Oct
# Rat
# 10    254.0
# 11    196.0
# 12    254.0
# 13    248.0
# 14    219.0
# 15    252.0
# 16    206.0
# 17    234.0
# 18    253.0
# Name: 20-Oct, dtype: float64
# 0.03479504957795143
# Day: 36
# 22-Oct
# Rat
# 10    262.0
# 11    204.0
# 12    261.0
# 13    256.0
# 14    226.0
# 15    259.0
# 16    213.0
# 17    240.0
# 18    261.0
# Name: 22-Oct, dtype: float64
# 0.03745651617646217
# Day: 37
# 23-Oct
# Rat
# 10    264.0
# 11    204.0
# 12    251.0
# 13    258.0
# 14    223.0
# 15    259.0
# 16    206.0
# 17    248.0
# 18    262.0
# Name: 23-Oct, dtype: float64
# 0.030887814238667488
# Day: 38
# 24-Oct
# Rat
# 10    265.0
# 11    205.0
# 12    267.0
# 13    268.0
# 14    229.0
# 15    273.0
# 16    214.0
# 17    253.0
# 18    273.0
# Name: 24-Oct, dtype: float64
# 0.03576090186834335
# Day: 39
# 25-Oct
# Rat
# 10    274.0
# 11    213.0
# 12    269.0
# 13    275.0
# 14    233.0
# 15    276.0
# 16    219.0
# 17    257.0
# 18    277.0
# Name: 25-Oct, dtype: float64
# 0.023084603250026703

# %% [markdown]
# ### Next, I'll check to see if the variance among groups for each day is equal using the Levene test
# **For days before Day 28, I will check if all the HFHS rats have equal variance to all the Control rats**
#
# **For days after Day 28, I will check if all 4 groups have equal variance**
#
# Results printed below will show the Day number and variance values for days when the body weight values among the groups was unequal

# %%
#----------------------------------------------------------
#Checked for 10x variance for each day
#----------------------------------------------------------
daynumber = 1
for day in body_weight.index:
    groupa = body_weight_anova.where((body_weight_anova.diet_and_schedule == "control ad lib") | (body_weight_anova.diet_and_schedule == "control restriction"))[day].dropna()
    groupb = body_weight_anova.where((body_weight_anova.diet_and_schedule == "HFHS ad lib") | (body_weight_anova.diet_and_schedule == "HFHS restriction"))[day].dropna()
    group1 = body_weight_anova.where(body_weight_anova.diet_and_schedule == "control ad lib")[day].dropna()
    group2 = body_weight_anova.where(body_weight_anova.diet_and_schedule == "control restriction")[day].dropna()
    group3 = body_weight_anova.where(body_weight_anova.diet_and_schedule == "HFHS ad lib")[day].dropna()
    group4 = body_weight_anova.where(body_weight_anova.diet_and_schedule == "HFHS restriction")[day].dropna()
    variances = {}
    if daynumber < 28:
        variances["Control Ad Lib"] = np.var(groupa)
        variances["HFHS Ad Lib"] = np.var(groupb)
    else:
        variances["Control Ad Lib"] = np.var(group1)
        variances["HFHS Ad Lib"] = np.var(group3)
        variances["Control Restriction"] = np.var(group2)
        variances["HFHS Restriction"] = np.var(group4)
    if max(variances.values()) >= (10 * min(variances.values())):
        print(day)
        print(variances)
    daynumber += 1
    
#----------------------------------------------------------
#Ran Levene Test
#----------------------------------------------------------
daynumber = 1
for day in body_weight.index:
    groupa = body_weight_anova.where((body_weight_anova.diet_and_schedule == "control ad lib") | (body_weight_anova.diet_and_schedule == "control restriction"))[day].dropna()
    groupb = body_weight_anova.where((body_weight_anova.diet_and_schedule == "HFHS ad lib") | (body_weight_anova.diet_and_schedule == "HFHS restriction"))[day].dropna()
    group1 = body_weight_anova.where(body_weight_anova.diet_and_schedule == "control ad lib")[day].dropna()
    group2 = body_weight_anova.where(body_weight_anova.diet_and_schedule == "control restriction")[day].dropna()
    group3 = body_weight_anova.where(body_weight_anova.diet_and_schedule == "HFHS ad lib")[day].dropna()
    group4 = body_weight_anova.where(body_weight_anova.diet_and_schedule == "HFHS restriction")[day].dropna()
    if daynumber < 28:
        s, p = stats.levene(groupa, groupb)
    else:
        s, p = stats.levene(group1, group2, group3, group4)
    if p < 0.05:
        print(daynumber)
        print(day)
        print(s)
        print(p)
    daynumber += 1
# Out:
# 11
# 27-Sep
# 4.409061110477712
# 0.04347561274847819

# %% [markdown]
# # Now, I will run a 2-way Type-1 ANOVA with TukeyHSD PostHoc Comparisions among all 4 diet groups (after day 28)

# %%
#----------------------------------------------------------
# Run ANOVA stats
#----------------------------------------------------------
def day_anova_analysis(day, anova_data):
    formula = 'Q("' + day + '") ~ C(Diet) + C(Feeding) + C(Diet):C(Feeding)'
    model = ols(formula, anova_data).fit()
    aov_table = anova_lm(model, typ=1)

    mc_interaction = statsmodels.stats.multicomp.MultiComparison(anova_data[day], anova_data['diet_and_schedule'])
    mc_interaction_results = mc_interaction.tukeyhsd()
    mc_interaction = pd.DataFrame(data=mc_interaction_results._results_table.data[1:], columns=mc_interaction_results._results_table.data[0])

    result = pd.concat([aov_table, mc_interaction], axis = 0, sort = False)
    # result.to_csv(group + "_statistical_analysis.csv")
     
    return result

daynumber = 1
for day in body_weight.index:
    result = day_anova_analysis(day, body_weight_anova)
    if (result["reject"].sum() > 0) and (daynumber > 25):
        print("Day " + str(daynumber))
        print(day)
        print(result.loc[[0, 1, 2, 3, 4, 5], ["group1", "group2", "p-adj", "reject"]])
    daynumber += 1
# Out:
# Day 26
# 12-Oct
#              group1               group2   p-adj reject
# 0       HFHS ad lib     HFHS restriction  0.9000  False
# 1       HFHS ad lib       control ad lib  0.0886  False
# 2       HFHS ad lib  control restriction  0.0718  False
# 3  HFHS restriction       control ad lib  0.0327   True
# 4  HFHS restriction  control restriction  0.0256   True
# 5    control ad lib  control restriction  0.9000  False
# Day 27
# 13-Oct
#              group1               group2   p-adj reject
# 0       HFHS ad lib     HFHS restriction  0.9000  False
# 1       HFHS ad lib       control ad lib  0.1205  False
# 2       HFHS ad lib  control restriction  0.0811  False
# 3  HFHS restriction       control ad lib  0.0324   True
# 4  HFHS restriction  control restriction  0.0201   True
# 5    control ad lib  control restriction  0.9000  False
# Day 28
# 14-Oct
#              group1               group2   p-adj reject
# 0       HFHS ad lib     HFHS restriction  0.9000  False
# 1       HFHS ad lib       control ad lib  0.1508  False
# 2       HFHS ad lib  control restriction  0.1204  False
# 3  HFHS restriction       control ad lib  0.0447   True
# 4  HFHS restriction  control restriction  0.0339   True
# 5    control ad lib  control restriction  0.9000  False
# Day 29
# 15-Oct
#              group1               group2   p-adj reject
# 0       HFHS ad lib     HFHS restriction  0.9000  False
# 1       HFHS ad lib       control ad lib  0.0965  False
# 2       HFHS ad lib  control restriction  0.0248   True
# 3  HFHS restriction       control ad lib  0.0719  False
# 4  HFHS restriction  control restriction  0.0168   True
# 5    control ad lib  control restriction  0.9000  False
# Day 30
# 16-Oct
#              group1               group2   p-adj reject
# 0       HFHS ad lib     HFHS restriction  0.9000  False
# 1       HFHS ad lib       control ad lib  0.1309  False
# 2       HFHS ad lib  control restriction  0.0222   True
# 3  HFHS restriction       control ad lib  0.0825  False
# 4  HFHS restriction  control restriction  0.0119   True
# 5    control ad lib  control restriction  0.8211  False
# Day 31
# 17-Oct
#              group1               group2   p-adj reject
# 0       HFHS ad lib     HFHS restriction  0.9000  False
# 1       HFHS ad lib       control ad lib  0.1477  False
# 2       HFHS ad lib  control restriction  0.0079   True
# 3  HFHS restriction       control ad lib  0.1514  False
# 4  HFHS restriction  control restriction  0.0074   True
# 5    control ad lib  control restriction  0.5513  False
# Day 32
# 18-Oct
#              group1               group2   p-adj reject
# 0       HFHS ad lib     HFHS restriction  0.9000  False
# 1       HFHS ad lib       control ad lib  0.1586  False
# 2       HFHS ad lib  control restriction  0.0070   True
# 3  HFHS restriction       control ad lib  0.1583  False
# 4  HFHS restriction  control restriction  0.0062   True
# 5    control ad lib  control restriction  0.5016  False
# Day 33
# 19-Oct
#              group1               group2   p-adj reject
# 0       HFHS ad lib     HFHS restriction  0.9000  False
# 1       HFHS ad lib       control ad lib  0.1354  False
# 2       HFHS ad lib  control restriction  0.0119   True
# 3  HFHS restriction       control ad lib  0.1287  False
# 4  HFHS restriction  control restriction  0.0103   True
# 5    control ad lib  control restriction  0.6678  False
# Day 34
# 20-Oct
#              group1               group2   p-adj reject
# 0       HFHS ad lib     HFHS restriction  0.9000  False
# 1       HFHS ad lib       control ad lib  0.2192  False
# 2       HFHS ad lib  control restriction  0.0050   True
# 3  HFHS restriction       control ad lib  0.2862  False
# 4  HFHS restriction  control restriction  0.0066   True
# 5    control ad lib  control restriction  0.3255  False
# Day 35
# 21-Oct
#              group1               group2   p-adj reject
# 0       HFHS ad lib     HFHS restriction  0.9000  False
# 1       HFHS ad lib       control ad lib  0.1673  False
# 2       HFHS ad lib  control restriction  0.0057   True
# 3  HFHS restriction       control ad lib  0.2943  False
# 4  HFHS restriction  control restriction  0.0118   True
# 5    control ad lib  control restriction  0.4390  False
# Day 36
# 22-Oct
#              group1               group2   p-adj reject
# 0       HFHS ad lib     HFHS restriction  0.9000  False
# 1       HFHS ad lib       control ad lib  0.2539  False
# 2       HFHS ad lib  control restriction  0.0034   True
# 3  HFHS restriction       control ad lib  0.3404  False
# 4  HFHS restriction  control restriction  0.0048   True
# 5    control ad lib  control restriction  0.2220  False
# Day 37
# 23-Oct
#              group1               group2   p-adj reject
# 0       HFHS ad lib     HFHS restriction  0.9000  False
# 1       HFHS ad lib       control ad lib  0.1859  False
# 2       HFHS ad lib  control restriction  0.0010   True
# 3  HFHS restriction       control ad lib  0.2695  False
# 4  HFHS restriction  control restriction  0.0010   True
# 5    control ad lib  control restriction  0.0977  False
# Day 38
# 24-Oct
#              group1               group2   p-adj reject
# 0       HFHS ad lib     HFHS restriction  0.9000  False
# 1       HFHS ad lib       control ad lib  0.2255  False
# 2       HFHS ad lib  control restriction  0.0018   True
# 3  HFHS restriction       control ad lib  0.3682  False
# 4  HFHS restriction  control restriction  0.0035   True
# 5    control ad lib  control restriction  0.1644  False
# Day 39
# 25-Oct
#              group1               group2   p-adj reject
# 0       HFHS ad lib     HFHS restriction  0.9000  False
# 1       HFHS ad lib       control ad lib  0.2007  False
# 2       HFHS ad lib  control restriction  0.0014   True
# 3  HFHS restriction       control ad lib  0.3000  False
# 4  HFHS restriction  control restriction  0.0023   True
# 5    control ad lib  control restriction  0.1587  False
# Day 40
# 26-Oct
#              group1               group2   p-adj reject
# 0       HFHS ad lib     HFHS restriction  0.9000  False
# 1       HFHS ad lib       control ad lib  0.1460  False
# 2       HFHS ad lib  control restriction  0.0010   True
# 3  HFHS restriction       control ad lib  0.2046  False
# 4  HFHS restriction  control restriction  0.0010   True
# 5    control ad lib  control restriction  0.1406  False
# Day 41
# 27-Oct
#              group1               group2   p-adj reject
# 0       HFHS ad lib     HFHS restriction  0.9000  False
# 1       HFHS ad lib       control ad lib  0.1535  False
# 2       HFHS ad lib  control restriction  0.0010   True
# 3  HFHS restriction       control ad lib  0.1646  False
# 4  HFHS restriction  control restriction  0.0010   True
# 5    control ad lib  control restriction  0.0950  False
# Day 42
# 28-Oct
#              group1               group2   p-adj reject
# 0       HFHS ad lib     HFHS restriction  0.9000  False
# 1       HFHS ad lib       control ad lib  0.1247  False
# 2       HFHS ad lib  control restriction  0.0015   True
# 3  HFHS restriction       control ad lib  0.1451  False
# 4  HFHS restriction  control restriction  0.0016   True
# 5    control ad lib  control restriction  0.2564  False
# Day 43
# 29-Oct
#              group1               group2   p-adj reject
# 0       HFHS ad lib     HFHS restriction  0.9000  False
# 1       HFHS ad lib       control ad lib  0.1785  False
# 2       HFHS ad lib  control restriction  0.0012   True
# 3  HFHS restriction       control ad lib  0.3358  False
# 4  HFHS restriction  control restriction  0.0028   True
# 5    control ad lib  control restriction  0.1563  False
# Day 44
# 30-Oct
#              group1               group2   p-adj reject
# 0       HFHS ad lib     HFHS restriction  0.9000  False
# 1       HFHS ad lib       control ad lib  0.1150  False
# 2       HFHS ad lib  control restriction  0.0010   True
# 3  HFHS restriction       control ad lib  0.2781  False
# 4  HFHS restriction  control restriction  0.0010   True
# 5    control ad lib  control restriction  0.0323   True
# Day 45
# 31-Oct
#              group1               group2   p-adj reject
# 0       HFHS ad lib     HFHS restriction  0.9000  False
# 1       HFHS ad lib       control ad lib  0.1406  False
# 2       HFHS ad lib  control restriction  0.0010   True
# 3  HFHS restriction       control ad lib  0.3648  False
# 4  HFHS restriction  control restriction  0.0010   True
# 5    control ad lib  control restriction  0.0610  False
# Day 46
# 1-Nov
#              group1               group2   p-adj reject
# 0       HFHS ad lib     HFHS restriction  0.9000  False
# 1       HFHS ad lib       control ad lib  0.1992  False
# 2       HFHS ad lib  control restriction  0.0010   True
# 3  HFHS restriction       control ad lib  0.4152  False
# 4  HFHS restriction  control restriction  0.0022   True
# 5    control ad lib  control restriction  0.0972  False
# Day 47
# 2-Nov
#              group1               group2   p-adj reject
# 0       HFHS ad lib     HFHS restriction  0.9000  False
# 1       HFHS ad lib       control ad lib  0.2589  False
# 2       HFHS ad lib  control restriction  0.0020   True
# 3  HFHS restriction       control ad lib  0.4481  False
# 4  HFHS restriction  control restriction  0.0044   True
# 5    control ad lib  control restriction  0.1481  False
# Day 48
# 3-Nov
#              group1               group2   p-adj reject
# 0       HFHS ad lib     HFHS restriction  0.9000  False
# 1       HFHS ad lib       control ad lib  0.1950  False
# 2       HFHS ad lib  control restriction  0.0013   True
# 3  HFHS restriction       control ad lib  0.3216  False
# 4  HFHS restriction  control restriction  0.0025   True
# 5    control ad lib  control restriction  0.1520  False
# Day 49
# 4-Nov
#              group1               group2   p-adj reject
# 0       HFHS ad lib     HFHS restriction  0.9000  False
# 1       HFHS ad lib       control ad lib  0.2560  False
# 2       HFHS ad lib  control restriction  0.0020   True
# 3  HFHS restriction       control ad lib  0.4407  False
# 4  HFHS restriction  control restriction  0.0045   True
# 5    control ad lib  control restriction  0.1526  False
# Day 50
# 5-Nov
#              group1               group2   p-adj reject
# 0       HFHS ad lib     HFHS restriction  0.9000  False
# 1       HFHS ad lib       control ad lib  0.2629  False
# 2       HFHS ad lib  control restriction  0.0028   True
# 3  HFHS restriction       control ad lib  0.4087  False
# 4  HFHS restriction  control restriction  0.0051   True
# 5    control ad lib  control restriction  0.1853  False
# Day 51
# 6-Nov
#              group1               group2   p-adj reject
# 0       HFHS ad lib     HFHS restriction  0.9000  False
# 1       HFHS ad lib       control ad lib  0.2141  False
# 2       HFHS ad lib  control restriction  0.0049   True
# 3  HFHS restriction       control ad lib  0.3228  False
# 4  HFHS restriction  control restriction  0.0083   True
# 5    control ad lib  control restriction  0.3304  False
# Day 52
# 7-Nov
#              group1               group2   p-adj reject
# 0       HFHS ad lib     HFHS restriction  0.9000  False
# 1       HFHS ad lib       control ad lib  0.2576  False
# 2       HFHS ad lib  control restriction  0.0051   True
# 3  HFHS restriction       control ad lib  0.3291  False
# 4  HFHS restriction  control restriction  0.0066   True
# 5    control ad lib  control restriction  0.2824  False
# Day 53
# 8-Nov
#              group1               group2   p-adj reject
# 0       HFHS ad lib     HFHS restriction  0.9000  False
# 1       HFHS ad lib       control ad lib  0.2348  False
# 2       HFHS ad lib  control restriction  0.0039   True
# 3  HFHS restriction       control ad lib  0.3514  False
# 4  HFHS restriction  control restriction  0.0067   True
# 5    control ad lib  control restriction  0.2648  False
# Day 54
# 9-Nov
#              group1               group2   p-adj reject
# 0       HFHS ad lib     HFHS restriction  0.9000  False
# 1       HFHS ad lib       control ad lib  0.2718  False
# 2       HFHS ad lib  control restriction  0.0083   True
# 3  HFHS restriction       control ad lib  0.4037  False
# 4  HFHS restriction  control restriction  0.0143   True
# 5    control ad lib  control restriction  0.3631  False

# %% [markdown]
# ### Sending all of the ANOVA + PostHoc Results to a CSV File

# %%
df = pd.DataFrame()

daynumber = 1
for day in body_weight.index:
    result = day_anova_analysis(day, body_weight_anova)
    result.iloc[0, -1] = day
    result.iloc[1, -1] = "Day: " + str(daynumber)
    df = df.append(result)
    daynumber += 1
df.fillna("").rename(index={0:'', 1:'', 2:'', 3:'', 4:'', 5:''}).to_csv("All days - ANOVA with TukeyHSD.csv")

# %% [markdown]
# ## Looking Closer into Each ANOVA and Tukey Result for Certain Groups

# %% [markdown]
# ### HFHS AdLib vs Control AdLib

# %% [markdown]
# #### PostHoc + ANOVA for significant days

# %%
daynumber = 1
for day in body_weight.index:
    result = day_anova_analysis(day, body_weight_anova)
    if (result.loc[[1], ["p-adj"]].values < 0.05) and (daynumber > 25):
        print("Day " + str(daynumber))
        print(day)
        print(result)
    daynumber += 1

# %% [markdown]
# No results, so no days when HFHS ad lib rats had significantly less or more body weight than Control ad lib rats after Day 28

# %% [markdown]
# ### HFHS Res vs Control Res

# %% [markdown]
# #### PostHoc + ANOVA for significant days

# %%
daynumber = 1
for day in body_weight.index:
    result = day_anova_analysis(day, body_weight_anova)
    if (result.loc[[4], ["p-adj"]].values < 0.05) and (daynumber > 25):
        print("Day " + str(daynumber))
        print(day)
        print(result.loc[[4], ["group1", "group2", "p-adj", "reject"]].to_string(index=False) + "\n")
        print(result.iloc[0:4, 0:5])
        print("\n")
    daynumber += 1
# Out:
# Day 26
# 12-Oct
#            group1               group2   p-adj reject
#  HFHS restriction  control restriction  0.0256   True
#
#                       df        sum_sq      mean_sq          F    PR(>F)
# C(Diet)              1.0   4959.378525  4959.378525  14.958558  0.000527
# C(Feeding)           1.0     10.653991    10.653991   0.032135  0.858899
# C(Diet):C(Feeding)   1.0     36.875421    36.875421   0.111224  0.741000
# Residual            31.0  10277.777778   331.541219        NaN       NaN
#
#
# Day 27
# 13-Oct
#            group1               group2   p-adj reject
#  HFHS restriction  control restriction  0.0201   True
#
#                       df        sum_sq      mean_sq          F    PR(>F)
# C(Diet)              1.0   5263.311298  5263.311298  14.713495  0.000575
# C(Feeding)           1.0     16.973262    16.973262   0.047448  0.828992
# C(Diet):C(Feeding)   1.0     93.367424    93.367424   0.261007  0.613049
# Residual            31.0  11089.319444   357.719982        NaN       NaN
#
#
# Day 28
# 14-Oct
#            group1               group2   p-adj reject
#  HFHS restriction  control restriction  0.0339   True
#
#                       df        sum_sq      mean_sq          F    PR(>F)
# C(Diet)              1.0   4940.343231  4940.343231  12.949253  0.001099
# C(Feeding)           1.0     25.959992    25.959992   0.068044  0.795931
# C(Diet):C(Feeding)   1.0     74.596380    74.596380   0.195526  0.661426
# Residual            31.0  11826.986111   381.515681        NaN       NaN
#
#
# Day 29
# 15-Oct
#            group1               group2   p-adj reject
#  HFHS restriction  control restriction  0.0168   True
#
#                       df        sum_sq      mean_sq          F    PR(>F)
# C(Diet)              1.0   6157.856303  6157.856303  15.575112  0.000424
# C(Feeding)           1.0     65.133789    65.133789   0.164743  0.687615
# C(Diet):C(Feeding)   1.0     92.576178    92.576178   0.234154  0.631862
# Residual            31.0  12256.319444   395.365143        NaN       NaN
#
#
# Day 30
# 16-Oct
#            group1               group2   p-adj reject
#  HFHS restriction  control restriction  0.0119   True
#
#                       df        sum_sq      mean_sq          F    PR(>F)
# C(Diet)              1.0   6633.804015  6633.804015  15.502139  0.000435
# C(Feeding)           1.0    102.425134   102.425134   0.239351  0.628119
# C(Diet):C(Feeding)   1.0    203.878788   203.878788   0.476432  0.495179
# Residual            31.0  13265.777778   427.928315        NaN       NaN
#
#
# Day 31
# 17-Oct
#            group1               group2   p-adj reject
#  HFHS restriction  control restriction  0.0074   True
#
#                       df        sum_sq      mean_sq          F    PR(>F)
# C(Diet)              1.0   7010.478525  7010.478525  16.094973  0.000353
# C(Feeding)           1.0    437.968806   437.968806   1.005509  0.323745
# C(Diet):C(Feeding)   1.0    325.185606   325.185606   0.746576  0.394199
# Residual            31.0  13502.652778   435.569444        NaN       NaN
#
#
# Day 32
# 18-Oct
#            group1               group2   p-adj reject
#  HFHS restriction  control restriction  0.0062   True
#
#                       df        sum_sq      mean_sq          F    PR(>F)
# C(Diet)              1.0   7311.372642  7311.372642  16.256057  0.000334
# C(Feeding)           1.0    502.674688   502.674688   1.117644  0.298596
# C(Diet):C(Feeding)   1.0    395.185606   395.185606   0.878653  0.355817
# Residual            31.0  13942.652778   449.762993        NaN       NaN
#
#
# Day 33
# 19-Oct
#            group1               group2   p-adj reject
#  HFHS restriction  control restriction  0.0103   True
#
#                       df        sum_sq      mean_sq          F    PR(>F)
# C(Diet)              1.0   7202.716060  7202.716060  15.656630  0.000412
# C(Feeding)           1.0    313.412656   313.412656   0.681269  0.415457
# C(Diet):C(Feeding)   1.0    254.094697   254.094697   0.552329  0.462963
# Residual            31.0  14261.319444   460.042563        NaN       NaN
#
#
# Day 34
# 20-Oct
#            group1               group2   p-adj reject
#  HFHS restriction  control restriction  0.0066   True
#
#                       df        sum_sq      mean_sq          F    PR(>F)
# C(Diet)              1.0   7694.685714  7694.685714  15.059519  0.000508
# C(Feeding)           1.0    990.121212   990.121212   1.937798  0.173815
# C(Diet):C(Feeding)   1.0    564.378788   564.378788   1.104564  0.301391
# Residual            31.0  15839.500000   510.951613        NaN       NaN
#
#
# Day 35
# 21-Oct
#            group1               group2   p-adj reject
#  HFHS restriction  control restriction  0.0118   True
#
#                       df        sum_sq      mean_sq          F    PR(>F)
# C(Diet)              1.0   7795.029785  7795.029785  14.619857  0.000595
# C(Feeding)           1.0    984.492870   984.492870   1.846452  0.184002
# C(Diet):C(Feeding)   1.0    327.409091   327.409091   0.614067  0.439207
# Residual            31.0  16528.611111   533.181004        NaN       NaN
#
#
# Day 36
# 22-Oct
#            group1               group2   p-adj reject
#  HFHS restriction  control restriction  0.0048   True
#
#                       df        sum_sq      mean_sq          F    PR(>F)
# C(Diet)              1.0   8058.272642  8058.272642  15.237482  0.000477
# C(Feeding)           1.0   1316.430580  1316.430580   2.489254  0.124777
# C(Diet):C(Feeding)   1.0    761.374158   761.374158   1.439691  0.239279
# Residual            31.0  16394.208333   528.845430        NaN       NaN
#
#
# Day 37
# 23-Oct
#            group1               group2  p-adj reject
#  HFHS restriction  control restriction  0.001   True
#
#                       df        sum_sq       mean_sq          F    PR(>F)
# C(Diet)              1.0  10927.089076  10927.089076  19.704610  0.000106
# C(Feeding)           1.0   2030.380669   2030.380669   3.661346  0.064962
# C(Diet):C(Feeding)   1.0   1210.612795   1210.612795   2.183075  0.149624
# Residual            31.0  17190.888889    554.544803        NaN       NaN
#
#
# Day 38
# 24-Oct
#            group1               group2   p-adj reject
#  HFHS restriction  control restriction  0.0035   True
#
#                       df        sum_sq      mean_sq          F    PR(>F)
# C(Diet)              1.0   9481.412605  9481.412605  16.235694  0.000337
# C(Feeding)           1.0   1857.552090  1857.552090   3.180818  0.084301
# C(Diet):C(Feeding)   1.0    882.451178   882.451178   1.511084  0.228223
# Residual            31.0  18103.555556   583.985663        NaN       NaN
#
#
# Day 39
# 25-Oct
#            group1               group2   p-adj reject
#  HFHS restriction  control restriction  0.0023   True
#
#                       df        sum_sq       mean_sq          F    PR(>F)
# C(Diet)              1.0  10249.069001  10249.069001  17.539670  0.000216
# C(Feeding)           1.0   1792.931769   1792.931769   3.068321  0.089721
# C(Diet):C(Feeding)   1.0    971.111532    971.111532   1.661905  0.206883
# Residual            31.0  18114.430556    584.336470        NaN       NaN
#
#
# Day 40
# 26-Oct
#            group1               group2  p-adj reject
#  HFHS restriction  control restriction  0.001   True
#
#                       df        sum_sq       mean_sq          F    PR(>F)
# C(Diet)              1.0  12094.039309  12094.039309  20.423432  0.000085
# C(Feeding)           1.0   1838.728560   1838.728560   3.105096  0.087907
# C(Diet):C(Feeding)   1.0   1110.006734   1110.006734   1.874489  0.180801
# Residual            31.0  18357.111111    592.164875        NaN       NaN
#
#
# Day 41
# 27-Oct
#            group1               group2  p-adj reject
#  HFHS restriction  control restriction  0.001   True
#
#                       df        sum_sq       mean_sq          F    PR(>F)
# C(Diet)              1.0  13302.343231  13302.343231  22.354119  0.000047
# C(Feeding)           1.0   1936.431373   1936.431373   3.254105  0.080971
# C(Diet):C(Feeding)   1.0   1541.833333   1541.833333   2.590997  0.117610
# Residual            31.0  18447.277778    595.073477        NaN       NaN
#
#
# Day 42
# 28-Oct
#            group1               group2   p-adj reject
#  HFHS restriction  control restriction  0.0016   True
#
#                       df        sum_sq       mean_sq          F    PR(>F)
# C(Diet)              1.0  12585.630252  12585.630252  20.059832  0.000095
# C(Feeding)           1.0   1322.213904   1322.213904   2.107434  0.156631
# C(Diet):C(Feeding)   1.0    913.185606    913.185606   1.455497  0.236775
# Residual            31.0  19449.541667    627.404570        NaN       NaN
#
#
# Day 43
# 29-Oct
#            group1               group2   p-adj reject
#  HFHS restriction  control restriction  0.0028   True
#
#                       df        sum_sq       mean_sq          F    PR(>F)
# C(Diet)              1.0  11869.806256  11869.806256  17.498960  0.000219
# C(Feeding)           1.0   2328.461180   2328.461180   3.432714  0.073459
# C(Diet):C(Feeding)   1.0    971.111532    971.111532   1.431653  0.240566
# Residual            31.0  21027.763889    678.314964        NaN       NaN
#
#
# Day 44
# 30-Oct
#            group1               group2  p-adj reject
#  HFHS restriction  control restriction  0.001   True
#
#                       df        sum_sq       mean_sq          F    PR(>F)
# C(Diet)              1.0  15876.900093  15876.900093  24.470140  0.000025
# C(Feeding)           1.0   3940.469796   3940.469796   6.073216  0.019471
# C(Diet):C(Feeding)   1.0   1729.263047   1729.263047   2.665212  0.112682
# Residual            31.0  20113.652778    648.827509        NaN       NaN
#
#
# Day 45
# 31-Oct
#            group1               group2  p-adj reject
#  HFHS restriction  control restriction  0.001   True
#
#                       df        sum_sq       mean_sq          F    PR(>F)
# C(Diet)              1.0  14530.870682  14530.870682  20.701994  0.000078
# C(Feeding)           1.0   3746.761834   3746.761834   5.337976  0.027687
# C(Diet):C(Feeding)   1.0   1351.542088   1351.542088   1.925529  0.175143
# Residual            31.0  21759.111111    701.906810        NaN       NaN
#
#
# Day 46
# 1-Nov
#            group1               group2   p-adj reject
#  HFHS restriction  control restriction  0.0022   True
#
#                       df        sum_sq       mean_sq          F    PR(>F)
# C(Diet)              1.0  13297.885714  13297.885714  17.651651  0.000208
# C(Feeding)           1.0   3269.609428   3269.609428   4.340089  0.045563
# C(Diet):C(Feeding)   1.0   1284.515572   1284.515572   1.705070  0.201234
# Residual            31.0  23353.875000    753.350806        NaN       NaN
#
#
# Day 47
# 2-Nov
#            group1               group2   p-adj reject
#  HFHS restriction  control restriction  0.0044   True
#
#                       df        sum_sq       mean_sq          F    PR(>F)
# C(Diet)              1.0  12397.715126  12397.715126  15.259105  0.000474
# C(Feeding)           1.0   2818.600218   2818.600218   3.469133  0.072025
# C(Diet):C(Feeding)   1.0   1223.495370   1223.495370   1.505878  0.229007
# Residual            31.0  25186.875000    812.479839        NaN       NaN
#
#
# Day 48
# 3-Nov
#            group1               group2   p-adj reject
#  HFHS restriction  control restriction  0.0025   True
#
#                       df        sum_sq       mean_sq          F    PR(>F)
# C(Diet)              1.0  14710.803361  14710.803361  17.482128  0.000220
# C(Feeding)           1.0   2756.602892   2756.602892   3.275911  0.080009
# C(Diet):C(Feeding)   1.0   1339.501684   1339.501684   1.591846  0.216474
# Residual            31.0  26085.777778    841.476703        NaN       NaN
#
#
# Day 49
# 4-Nov
#            group1               group2   p-adj reject
#  HFHS restriction  control restriction  0.0045   True
#
#                       df        sum_sq       mean_sq          F    PR(>F)
# C(Diet)              1.0  12886.601681  12886.601681  15.283292  0.000470
# C(Feeding)           1.0   2877.015251   2877.015251   3.412091  0.074284
# C(Diet):C(Feeding)   1.0   1255.273148   1255.273148   1.488733  0.231614
# Residual            31.0  26138.652778    843.182348        NaN       NaN
#
#
# Day 50
# 5-Nov
#            group1               group2   p-adj reject
#  HFHS restriction  control restriction  0.0051   True
#
#                       df        sum_sq       mean_sq          F    PR(>F)
# C(Diet)              1.0  13003.137348  13003.137348  14.952819  0.000528
# C(Feeding)           1.0   2578.788770   2578.788770   2.965451  0.095026
# C(Diet):C(Feeding)   1.0   1248.015152   1248.015152   1.435142  0.240007
# Residual            31.0  26957.944444    869.611111        NaN       NaN
#
#
# Day 51
# 6-Nov
#            group1               group2   p-adj reject
#  HFHS restriction  control restriction  0.0083   True
#
#                       df        sum_sq       mean_sq          F    PR(>F)
# C(Diet)              1.0  13650.072923  13650.072923  14.635033  0.000592
# C(Feeding)           1.0   1953.107645   1953.107645   2.094040  0.157912
# C(Diet):C(Feeding)   1.0    895.909512    895.909512   0.960556  0.334634
# Residual            31.0  28913.652778    932.698477        NaN       NaN
#
#
# Day 52
# 7-Nov
#            group1               group2   p-adj reject
#  HFHS restriction  control restriction  0.0066   True
#
#                       df        sum_sq       mean_sq          F    PR(>F)
# C(Diet)              1.0  13885.903361  13885.903361  14.538740  0.000613
# C(Feeding)           1.0   2015.163498   2015.163498   2.109905  0.156396
# C(Diet):C(Feeding)   1.0   1199.218855   1199.218855   1.255599  0.271092
# Residual            31.0  29608.000000    955.096774        NaN       NaN
#
#
# Day 53
# 8-Nov
#            group1               group2   p-adj reject
#  HFHS restriction  control restriction  0.0067   True
#
#                       df        sum_sq       mean_sq          F    PR(>F)
# C(Diet)              1.0  14220.381046  14220.381046  14.792524  0.000559
# C(Feeding)           1.0   2307.380570   2307.380570   2.400216  0.131468
# C(Diet):C(Feeding)   1.0   1116.852273   1116.852273   1.161788  0.289411
# Residual            31.0  29800.986111    961.322133        NaN       NaN
#
#
# Day 54
# 9-Nov
#            group1               group2   p-adj reject
#  HFHS restriction  control restriction  0.0143   True
#
#                       df        sum_sq       mean_sq          F    PR(>F)
# C(Diet)              1.0  12827.436134  12827.436134  12.761843  0.001180
# C(Feeding)           1.0   1986.674688   1986.674688   1.976516  0.169702
# C(Diet):C(Feeding)   1.0    872.727273    872.727273   0.868265  0.358637
# Residual            31.0  31159.333333   1005.139785        NaN       NaN

# %% [markdown]
# ### Send the Results to a CSV File

# %%
df = pd.DataFrame()

daynumber = 1
for day in body_weight.index:
    result = day_anova_analysis(day, body_weight_anova)
    if (result.loc[[4], ["p-adj"]].values < 0.05) and (daynumber > 25):
        result.iloc[0, -1] = day
        result.iloc[1, -1] = "Day: " + str(daynumber)
        df = df.append(result.iloc[[0, 1, 2, 3, 8],:])
    daynumber += 1
df.fillna("").rename(index={0:'', 1:'', 2:'', 3:'', 4:'', 5:''}).to_csv("HFHSRes vs ControlRes significant days - ANOVA with TukeyHSD.csv")

# %% [markdown]
# ### Control Res vs Control AdLib

# %% [markdown]
# #### PostHoc + ANOVA for significant days

# %%
daynumber = 1
for day in body_weight.index:
    result = day_anova_analysis(day, body_weight_anova)
    if (result.loc[[5], ["p-adj"]].values < 0.05) and (daynumber > 25):
        print("Day " + str(daynumber))
        print(day)
        print(result.loc[[5], ["group1", "group2", "p-adj"]].to_string(index=False) + "\n")
        print(result.iloc[0:4, 0:5])
        print("\n")
    daynumber += 1
# Out:
# Day 44
# 30-Oct
#          group1               group2   p-adj
#  control ad lib  control restriction  0.0323
#
#                      df        sum_sq       mean_sq          F    PR(>F)
# C(Diet)             1.0  15876.900093  15876.900093  24.470140  0.000025
# C(Feeding)          1.0   3940.469796   3940.469796   6.073216  0.019471
# C(Diet):C(Feeding)  1.0   1729.263047   1729.263047   2.665212  0.112682

# %% [markdown]
# ### Send the Results to a CSV File

# %%
df = pd.DataFrame()

daynumber = 1
for day in body_weight.index:
    result = day_anova_analysis(day, body_weight_anova)
    if (result.loc[[5], ["p-adj"]].values < 0.05) and (daynumber > 25):
        result.iloc[0, -1] = day
        result.iloc[1, -1] = "Day: " + str(daynumber)
        df = df.append(result.iloc[[0, 1, 2, 3, 9],:])
    daynumber += 1
df.fillna("").rename(index={0:'', 1:'', 2:'', 3:'', 4:'', 5:''}).to_csv("ControlAdLib vs ControlRes significant days - ANOVA with TukeyHSD.csv")

# %% [markdown]
# ### HFHS Res vs HFHS AdLib

# %% [markdown]
# #### PostHoc + ANOVA for significant days

# %%
daynumber = 1
for day in body_weight.index:
    result = day_anova_analysis(day, body_weight_anova)
    if (result.loc[[0], ["p-adj"]].values < 0.05) and (daynumber > 25):
        print("Day " + str(daynumber))
        print(day)
        print(result.loc[[0], ["group1", "group2", "p-adj"]].to_string(index=False) + "\n")
        print(result.iloc[0:3, 0:5])
        print("\n")
    daynumber += 1

# %% [markdown]
# ## 3. Mann-U Whitney Test

# %%
# Add experimental group labels to metafile data
metafile['group']=metafile.Diet+' '+metafile.Feeding

def MannUWhitneyAnalysis(column_name, dataframe, interest_list, measurement_of_interest):
    # Create the columns for the Mann-U Whitney Analysis Table
    groups = metafile.group.unique()
    column_names = [column_name, "group1", "group2", "p_value"]
    df = pd.DataFrame(columns = column_names)

    # Separate dataframes by experimental condition
    feeding = metafile.Feeding.unique()
    diet   = metafile.Diet.unique()
    group_dict={}
    for x in diet:
            for y in feeding:
                group = str(x)+' '+str(y)
                ids = metafile[(metafile.Diet==x) & (metafile.Feeding==y)].index
                by_group = dataframe.loc[ids]
                by_group.dropna(inplace = True)
                group_dict[group]=by_group

    # For each metabolite/hormone, compare expression between 4 experimental groups. 
    # Save p-values and separate into significant and non-significant dataframes
    i=0
    for c in interest_list:

        for x in groups:
            group1 = group_dict[x][c]

            for y in groups:
                if(y!= x):
                    group2 = group_dict[y][c]
                    u_statistic, pVal = stats.mannwhitneyu(group1, group2)
                    df.loc[i]=[c, x, y, pVal]
                    i+=1
    df.to_csv(measurement_of_interest + '_p_values_Mann_Whitney.csv')
    # Sepatate significantly expressed genes (p<0.05) and  Remove repeated comparisons
    significant = df[df.p_value<0.05].drop_duplicates(subset='p_value').reset_index(drop=True)
    # Save significant genes to .csv file
    significant.to_csv('significant_' + measurement_of_interest + '_p_values_Mann_Whitney.csv')
    return significant
    
significant_days = MannUWhitneyAnalysis("Day", body_weight_anova, body_weight.index, "Body_weight")

# Check the significant days for control restriction vs control ad lib
significant_days[significant_days.group2 == "control restriction"]
# Out:
#         Day          group1               group2   p_value
# 104  20-Oct  control ad lib  control restriction  0.028622
# 114  24-Oct  control ad lib  control restriction  0.016529
# 118  25-Oct  control ad lib  control restriction  0.031640
# 124  27-Oct  control ad lib  control restriction  0.023359
# 128  28-Oct  control ad lib  control restriction  0.046614
# 131  29-Oct  control ad lib  control restriction  0.021024
# 134  30-Oct  control ad lib  control restriction  0.009611
# 137  31-Oct  control ad lib  control restriction  0.010842
# 141   3-Nov  control ad lib  control restriction  0.025908
# 144   6-Nov  control ad lib  control restriction  0.031708

# %% [markdown]
# # B. Total Fat Mass

# %% [markdown]
# ## 1. 2-Sample T-Test Analysis
# I will use Student's t-test (default version in stats_ind) to compare fat pad mass between diet groups

# %%
fat_list = ["total_fat_pad", "total_abdominal_fat", "total_gonadal_fat", "liver_weight"]
t_test_results = {}
for group in fat_list:
    group1 = master_data.where(master_data.group == "control ad lib")[group].dropna()
    group2 = master_data.where(master_data.group == "control restriction")[group].dropna()
    group3 = master_data.where(master_data.group == "HFHS ad lib")[group].dropna()
    group4 = master_data.where(master_data.group == "HFHS restriction")[group].dropna()
    # Control AdLib vs Control Restricted
    t_test_results[group + "- Control AdLib vs Control Restricted"] = stats.ttest_ind(group1,group2)
    # Control Adlib vs HFHS Ad Lib
    t_test_results[group + "- Control Adlib vs HFHS Ad Lib"] = stats.ttest_ind(group1,group3)
    # HFHS AdLib vs HFHS Restricted
    t_test_results[group + "- HFHS AdLib vs HFHS Restricted"] = stats.ttest_ind(group3,group4)
    # Control Restricted vs HFHS Restricted
    t_test_results[group + "- Control Restricted vs HFHS Restricted"] = stats.ttest_ind(group2,group4)
results_df = pd.DataFrame.from_dict(t_test_results,orient='Index')
results_df.columns = ['statistic','pvalue']
#results_df
significant_group_v2 = results_df[results_df.pvalue<0.05].drop_duplicates(subset='pvalue')
significant_group_v2
# Out:
#                                                     statistic    pvalue
# total_fat_pad- Control Adlib vs HFHS Ad Lib         -2.853223  0.012087
# total_fat_pad- Control Restricted vs HFHS Restr...  -3.608719  0.002355
# total_abdominal_fat- Control Adlib vs HFHS Ad Lib   -2.358751  0.032323
# total_abdominal_fat- Control Restricted vs HFHS...  -3.633199  0.002237
# total_gonadal_fat- Control Adlib vs HFHS Ad Lib     -2.590460  0.020484
# total_gonadal_fat- Control Restricted vs HFHS R...  -2.583062  0.020017

# %% [markdown]
# ## 2. ANOVA Analysis with PostHoc Tukey

# %% [markdown]
# ### First, I'll check for normality with the Shapiro-Wilk Test

# %%
for group in master_data["group"].unique():
    w, p = stats.shapiro(master_data.where(master_data.group == group)["total_fat_pad"].dropna())
    print(p)
# Out:
# 0.6800441145896912
# 0.12340932339429855
# 0.4587366580963135
# 0.8304331302642822

# %% [markdown]
# ### Next, I'll check for equal variance with the Levene Test

# %%
variances = {}
for group in master_data["group"].unique():
    variances[str(group)] = np.var(master_data.where(master_data.group == group)["total_fat_pad"].dropna())
        

control_ad_lib_fat = master_data.where(master_data.group == "control ad lib")["total_fat_pad"].dropna()
control_restriction_fat = master_data.where(master_data.group == "control restriction")["total_fat_pad"].dropna()
HFHS_ad_lib_fat = master_data.where(master_data.group == "HFHS ad lib")["total_fat_pad"].dropna()
HFHS_restriction_fat = master_data.where(master_data.group == "HFHS restriction")["total_fat_pad"].dropna()

s, p = stats.levene(control_ad_lib_fat, control_restriction_fat, HFHS_ad_lib_fat, HFHS_restriction_fat)
if (p < 0.05) | (max(variances.values()) >= (3 * min(variances.values()))):
    print(p)
    print(variances)
# Out:
# 0.004291396222530111
# {'control ad lib': 8.291111111111112, 'control restriction': 4.638024691358023, 'HFHS ad lib': 40.94859375, 'HFHS restriction': 8.803950617283949}

# %% [markdown]
# ### Now, I can run ANOVA and Tukey PostHoc

# %%
#----------------------------------------------------------
# Run ANOVA stats
#----------------------------------------------------------
def anova_analysis(metabolite, anova_data):
    formula = metabolite + ' ~ C(diet) + C(feeding_schedule) + C(diet):C(feeding_schedule)'
    model = ols(formula, anova_data).fit()
    aov_table = anova_lm(model, typ=1)
    
    mc_interaction = statsmodels.stats.multicomp.MultiComparison(anova_data[metabolite], anova_data['group'])
    mc_interaction_results = mc_interaction.tukeyhsd()
    mc_interaction = pd.DataFrame(data=mc_interaction_results._results_table.data[1:], columns=mc_interaction_results._results_table.data[0])
    
    result = pd.concat([aov_table, mc_interaction], axis = 0, sort = False)

    return result

total_fat_mass_anova = anova_analysis("total_fat_pad", master_data)

print(total_fat_mass_anova.loc[[0, 1, 4, 5], ["group1", "group2", "p-adj"]].to_string(index = False))
print(total_fat_mass_anova.iloc[0:3, 0:5])
# Out:
#            group1               group2   p-adj
#       HFHS ad lib     HFHS restriction  0.3955
#       HFHS ad lib       control ad lib  0.0058
#  HFHS restriction  control restriction  0.0950
#    control ad lib  control restriction  0.9000
#                               df      sum_sq     mean_sq          F    PR(>F)
# C(diet)                      1.0  297.633348  297.633348  17.635458  0.000209
# C(feeding_schedule)          1.0   31.590319   31.590319   1.871799  0.181105
# C(diet):C(feeding_schedule)  1.0   13.651519   13.651519   0.808884  0.375384

# %% [markdown]
# ### Send Results to CSV File

# %%
total_fat_mass_anova.fillna("").rename(index={0:'', 1:'', 2:'', 3:'', 4:'', 5:''}).to_csv("Total Fat Mass - ANOVA with TukeyHSD.csv")

# %% [markdown]
# ## 3. Mann-U Whitney Analysis

# %%
significant_fat = MannUWhitneyAnalysis("Total Fat Mass", master_data, fat_list, "Total_fat_mass")
significant_fat
# Out:
#          Total Fat Mass               group1               group2   p_value
# 0         total_fat_pad       control ad lib          HFHS ad lib  0.028187
# 1         total_fat_pad       control ad lib     HFHS restriction  0.008502
# 2         total_fat_pad  control restriction          HFHS ad lib  0.005506
# 3         total_fat_pad  control restriction     HFHS restriction  0.004019
# 4         total_fat_pad          HFHS ad lib  control restriction  0.005506
# 5   total_abdominal_fat       control ad lib          HFHS ad lib  0.035868
# 6   total_abdominal_fat       control ad lib     HFHS restriction  0.010741
# 7   total_abdominal_fat  control restriction          HFHS ad lib  0.014885
# 8   total_abdominal_fat  control restriction     HFHS restriction  0.002348
# 9   total_abdominal_fat          HFHS ad lib       control ad lib  0.035868
# 10    total_gonadal_fat       control ad lib          HFHS ad lib  0.009937
# 11    total_gonadal_fat       control ad lib     HFHS restriction  0.012134
# 12    total_gonadal_fat  control restriction          HFHS ad lib  0.005418
# 13    total_gonadal_fat  control restriction     HFHS restriction  0.003494
# 14         liver_weight       control ad lib          HFHS ad lib  0.031789
# 15         liver_weight  control restriction          HFHS ad lib  0.002942
# 16         liver_weight          HFHS ad lib  control restriction  0.002942
